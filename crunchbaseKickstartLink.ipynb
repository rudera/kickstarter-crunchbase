# %%
import numpy as np
import pandas as pd
from glob import glob
import json

kickstarter_files = sorted(glob('eship_data_share/kickstarter/csv/*.csv'))
ks_df = pd.concat((pd.read_csv(file) for file in kickstarter_files), ignore_index = True)
ks_df
# Out:
#                                                  facebook  \
# 0       ['http://facebook.com/EatChowza', 'http://face...
# 1                  ['https://www.facebook.com/503562415']
# 2                 ['https://www.facebook.com/1508190198']
# 3          ['https://www.facebook.com/10221886627381570']
# 4       ['https://www.facebook.com/smartphonescopemoun...
# ...                                                   ...
# 711122                                                 []
# 711123  ['https://www.facebook.com/LAmourOrLess', 'htt...
# 711124                                                 []
# 711125      ['https://www.facebook.com/1648192562175009']
# 711126  ['https://www.facebook.com/fuchsiashoes', 'htt...
#
#                                                   twitter linkedin github  \
# 0                                                      []       []     []
# 1       ['http://twitter.com/amyfloretta', 'http://twi...       []     []
# 2                                                      []       []     []
# 3                                                      []       []     []
# 4       ['http://twitter.com/smartphonemount', 'http:/...       []     []
# ...                                                   ...      ...    ...
# 711122  ['https://twitter.com/acerami', 'https://twitt...       []     []
# 711123  ['https://twitter.com/jennyphoria', 'https://t...       []     []
# 711124  ['https://twitter.com/SimFans', 'https://twitt...       []     []
# 711125                                                 []       []     []
# 711126  ['https://twitter.com/fuchsiashoes', 'https://...       []     []
#
#        email            id type
# 0         []  1.666327e+09    c
# 1         []  1.547131e+08    c
# 2         []  2.680785e+08    c
# 3         []  1.199866e+09    c
# 4         []  1.696516e+09    c
# ...      ...           ...  ...
# 711122    []  1.078918e+09    c
# 711123    []  1.468955e+09    c
# 711124    []  2.098330e+09    c
# 711125    []  1.332155e+09    c
# 711126    []  4.099851e+08    c
#
# [711127 rows x 7 columns]

# %%
cb_df = pd.read_csv('eship_data_share/crunchbase/selectorg_11132020.csv', low_memory=False)
cb_df
# Out:
#                              _id                         data.uuid  \
# 0       5bc4821cf27e62f65c1aa0c4  5b3e1a8a659038da11ca321ae673d17a
# 1       5bc4821cf27e62f65c1aa0c5  65609a0678e0195e7032ff9353b82b46
# 2       5bc4821cf27e62f65c1aa0c6  2485430c0d4d900911bd6ee870e594c8
# 3       5bc4821cf27e62f65c1aa0c7  48fa12215094286d80df0275652cad08
# 4       5bc4821cf27e62f65c1aa0c8  c127e1bdf837549254fda5d8e128e7fc
# ...                          ...                               ...
# 655543  5bc48a5cf27e62f65c24a17b  39ea80735fe648c69d0837e5a4db97af
# 655544  5bc48a5cf27e62f65c24a17c  bab3914867784403ac5d303c096e228e
# 655545  5bc48a5cf27e62f65c24a17d  d6574842db0748508eb6fa891ce7cc7a
# 655546  5bc48a5cf27e62f65c24a17e  0cd754a82a124886b9cf2a66a589242f
# 655547  5bc48a5cf27e62f65c24a17f  7c3ce388e31472fb0708e450848f6c8d
#
#        data.properties.name data.properties.also_known_as  \
# 0               #5 Magazine                           NaN
# 1                   #Angels                           NaN
# 2                   apiware                           NaN
# 3                  #Captain                           NaN
# 4          (e) Science News                           NaN
# ...                     ...                           ...
# 655543                  歪脸网                           NaN
# 655544                   王猛                           NaN
# 655545           稲葉サーバーデザイン                           NaN
# 655546                 香港便民                           NaN
# 655547           Visualwise                           NaN
#
#                         data.properties.short_description  \
# 0       #5 Magazine is a U.K.-based company that provi...
# 1       #Angels is a team of experienced operators col...
# 2              Development, Management & Support of API's
# 3       Captain is a feed of texts, photos and videos ...
# 4       (e) Science News is a Canada-based online plat...
# ...                                                   ...
# 655543  WaiLian developed an AI operating system for i...
# 655544                                               事业单位
# 655545                                                 ..
# 655546                   WeChat Mini Program in Hong Kong
# 655547  Visual-Wise makes virtual reality accessible t...
#
#                               data.properties.description  \
# 0       &nbsp;#5 Magazine is the world’s first multi-p...
# 1       #Angels is a team of experienced operators col...
# 2                                                     NaN
# 3       Bring popular posts from social networks at th...
# 4       (e) Science News is an online platform, ensuri...
# ...                                                   ...
# 655543                                                NaN
# 655544                                                NaN
# 655545                                                NaN
# 655546                                                NaN
# 655547  Visual-Wise makes virtual reality accessible t...
#
#                         data.properties.profile_image_url  \
# 0       http://public.crunchbase.com/t_api_images/v147...
# 1       http://public.crunchbase.com/t_api_images/v147...
# 2       http://public.crunchbase.com/t_api_images/v142...
# 3       http://public.crunchbase.com/t_api_images/v142...
# 4       http://public.crunchbase.com/t_api_images/v142...
# ...                                                   ...
# 655543  http://public.crunchbase.com/t_api_images/kxsl...
# 655544                                                NaN
# 655545  http://public.crunchbase.com/t_api_images/acub...
# 655546  http://public.crunchbase.com/t_api_images/jk6f...
# 655547  http://public.crunchbase.com/t_api_images/v142...
#
#        data.properties.primary_role data.properties.founded_on  \
# 0                           company                 2007-01-01
# 1                          investor                 2015-03-04
# 2                           company                 2015-04-15
# 3                           company                        NaN
# 4                           company                 2009-01-01
# ...                             ...                        ...
# 655543                      company                 2017-01-01
# 655544                      company                 1995-04-04
# 655545                      company                        NaN
# 655546                      company                 2018-01-01
# 655547                      company                 2014-08-01
#
#         data.properties.founded_on_trust_code  ...  \
# 0                                         5.0  ...
# 1                                         7.0  ...
# 2                                         7.0  ...
# 3                                         NaN  ...
# 4                                         5.0  ...
# ...                                       ...  ...
# 655543                                    5.0  ...
# 655544                                    7.0  ...
# 655545                                    NaN  ...
# 655546                                    5.0  ...
# 655547                                    7.0  ...
#
#         data.relationships.websites.paging.total_items  \
# 0                                                    3
# 1                                                    2
# 2                                                    2
# 3                                                    2
# 4                                                    3
# ...                                                ...
# 655543                                               1
# 655544                                               0
# 655545                                               1
# 655546                                               1
# 655547                                               2
#
#         data.relationships.websites.paging.first_page_url  \
# 0       https://api.crunchbase.com/v3.1/organizations/...
# 1       https://api.crunchbase.com/v3.1/organizations/...
# 2       https://api.crunchbase.com/v3.1/organizations/...
# 3       https://api.crunchbase.com/v3.1/organizations/...
# 4       https://api.crunchbase.com/v3.1/organizations/...
# ...                                                   ...
# 655543  https://api.crunchbase.com/v3.1/organizations/...
# 655544  https://api.crunchbase.com/v3.1/organizations/...
# 655545  https://api.crunchbase.com/v3.1/organizations/...
# 655546  https://api.crunchbase.com/v3.1/organizations/...
# 655547  https://api.crunchbase.com/v3.1/organizations/...
#
#        data.relationships.websites.paging.sort_order  \
# 0                                        not_ordered
# 1                                        not_ordered
# 2                                        not_ordered
# 3                                        not_ordered
# 4                                        not_ordered
# ...                                              ...
# 655543                                   not_ordered
# 655544                                   not_ordered
# 655545                                   not_ordered
# 655546                                   not_ordered
# 655547                                   not_ordered
#
#                         data.relationships.websites.items  \
# 0       [{'type': 'Website', 'uuid': '5b3e1a8a659038da...
# 1       [{'type': 'Website', 'uuid': '65609a0678e0195e...
# 2       [{'type': 'Website', 'uuid': '2485430c0d4d9009...
# 3       [{'type': 'Website', 'uuid': '48fa12215094286d...
# 4       [{'type': 'Website', 'uuid': 'c127e1bdf8375492...
# ...                                                   ...
# 655543  [{'type': 'Website', 'uuid': '39ea80735fe648c6...
# 655544                                                 []
# 655545  [{'type': 'Website', 'uuid': 'd6574842db074850...
# 655546  [{'type': 'Website', 'uuid': '0cd754a82a124886...
# 655547  [{'type': 'Website', 'uuid': '7c3ce388e31472fb...
#
#                                   twitter  \
# 0                 http://twitter.com/5mag
# 1         https://twitter.com/HelloAngels
# 2       https://www.twitter.com/apiwareio
# 3         https://twitter.com/Captain_App
# 4        https://twitter.com/esciencenews
# ...                                   ...
# 655543                                NaN
# 655544                                NaN
# 655545                                NaN
# 655546                                NaN
# 655547    https://twitter.com/Visual_Wise
#
#                                      facebook                        homepage  \
# 0           http://www.facebook.com/5magazine                 http://5mag.co/
# 1                                         NaN          http://helloangels.co/
# 2                                         NaN           http://www.apiware.io
# 3                                         NaN          http://onecaptain.com/
# 4       https://www.facebook.com/esciencenews        http://esciencenews.com/
# ...                                       ...                             ...
# 655543                                    NaN             http://91ylian.com/
# 655544                                    NaN                             NaN
# 655545                                    NaN  https://inaba-serverdesign.jp/
# 655546                                    NaN             http://www.hk4w.com
# 655547                                    NaN    https://www.visual-wise.com/
#
#        linkedin        fb_key        tw_key
# 0           NaN     5magazine          5mag
# 1           NaN           NaN   helloangels
# 2           NaN           NaN     apiwareio
# 3           NaN           NaN   captain_app
# 4           NaN  esciencenews  esciencenews
# ...         ...           ...           ...
# 655543      NaN           NaN           NaN
# 655544      NaN           NaN           NaN
# 655545      NaN           NaN           NaN
# 655546      NaN           NaN           NaN
# 655547      NaN           NaN   visual_wise
#
# [655548 rows x 23 columns]

# %%
#ks_df.at[1,'twitter']
#ks_df.at[1,'twitter'] = eval(ks_df.at[1,'twitter'])[0].split('//')[1]

# %%
#idx = cb_df.index[cb_df['twitter'] == 'https://twitter.com/Captain_App']
#cb_df.at[idx[0],'twitter'].split('//')[1]

# %%
for index, row in ks_df.iterrows():
    if ks_df.at[index, 'twitter'] != '[]':
        ks_df.at[index, 'twitter'] = eval(ks_df.at[index,'twitter'])[0].split('//')[1]
ks_df
# Out:
#                                                  facebook  \
# 0       ['http://facebook.com/EatChowza', 'http://face...
# 1                  ['https://www.facebook.com/503562415']
# 2                 ['https://www.facebook.com/1508190198']
# 3          ['https://www.facebook.com/10221886627381570']
# 4       ['https://www.facebook.com/smartphonescopemoun...
# ...                                                   ...
# 711122                                                 []
# 711123  ['https://www.facebook.com/LAmourOrLess', 'htt...
# 711124                                                 []
# 711125      ['https://www.facebook.com/1648192562175009']
# 711126  ['https://www.facebook.com/fuchsiashoes', 'htt...
#
#                             twitter linkedin github email            id type
# 0                                []       []     []    []  1.666327e+09    c
# 1           twitter.com/amyfloretta       []     []    []  1.547131e+08    c
# 2                                []       []     []    []  2.680785e+08    c
# 3                                []       []     []    []  1.199866e+09    c
# 4       twitter.com/smartphonemount       []     []    []  1.696516e+09    c
# ...                             ...      ...    ...   ...           ...  ...
# 711122          twitter.com/acerami       []     []    []  1.078918e+09    c
# 711123      twitter.com/jennyphoria       []     []    []  1.468955e+09    c
# 711124          twitter.com/SimFans       []     []    []  2.098330e+09    c
# 711125                           []       []     []    []  1.332155e+09    c
# 711126     twitter.com/fuchsiashoes       []     []    []  4.099851e+08    c
#
# [711127 rows x 7 columns]

# %%
#pd.isna(cb_df.at[655544, 'twitter'])
cb_df.at[1262, 'twitter'].split('//')
len(cb_df.at[439429, 'twitter'].split('//'))
# Out:
# 1

# %%
for index, row in cb_df.iterrows():
    if pd.isna(cb_df.at[index, 'twitter']):
        continue
    elif len(cb_df.at[index, 'twitter'].split('//')) < 2:
        continue
    else:
        cb_df.at[index, 'twitter'] = cb_df.at[index, 'twitter'].split('//')[1]
cb_df
# Out:
#                              _id                         data.uuid  \
# 0       5bc4821cf27e62f65c1aa0c4  5b3e1a8a659038da11ca321ae673d17a
# 1       5bc4821cf27e62f65c1aa0c5  65609a0678e0195e7032ff9353b82b46
# 2       5bc4821cf27e62f65c1aa0c6  2485430c0d4d900911bd6ee870e594c8
# 3       5bc4821cf27e62f65c1aa0c7  48fa12215094286d80df0275652cad08
# 4       5bc4821cf27e62f65c1aa0c8  c127e1bdf837549254fda5d8e128e7fc
# ...                          ...                               ...
# 655543  5bc48a5cf27e62f65c24a17b  39ea80735fe648c69d0837e5a4db97af
# 655544  5bc48a5cf27e62f65c24a17c  bab3914867784403ac5d303c096e228e
# 655545  5bc48a5cf27e62f65c24a17d  d6574842db0748508eb6fa891ce7cc7a
# 655546  5bc48a5cf27e62f65c24a17e  0cd754a82a124886b9cf2a66a589242f
# 655547  5bc48a5cf27e62f65c24a17f  7c3ce388e31472fb0708e450848f6c8d
#
#        data.properties.name data.properties.also_known_as  \
# 0               #5 Magazine                           NaN
# 1                   #Angels                           NaN
# 2                   apiware                           NaN
# 3                  #Captain                           NaN
# 4          (e) Science News                           NaN
# ...                     ...                           ...
# 655543                  歪脸网                           NaN
# 655544                   王猛                           NaN
# 655545           稲葉サーバーデザイン                           NaN
# 655546                 香港便民                           NaN
# 655547           Visualwise                           NaN
#
#                         data.properties.short_description  \
# 0       #5 Magazine is a U.K.-based company that provi...
# 1       #Angels is a team of experienced operators col...
# 2              Development, Management & Support of API's
# 3       Captain is a feed of texts, photos and videos ...
# 4       (e) Science News is a Canada-based online plat...
# ...                                                   ...
# 655543  WaiLian developed an AI operating system for i...
# 655544                                               事业单位
# 655545                                                 ..
# 655546                   WeChat Mini Program in Hong Kong
# 655547  Visual-Wise makes virtual reality accessible t...
#
#                               data.properties.description  \
# 0       &nbsp;#5 Magazine is the world’s first multi-p...
# 1       #Angels is a team of experienced operators col...
# 2                                                     NaN
# 3       Bring popular posts from social networks at th...
# 4       (e) Science News is an online platform, ensuri...
# ...                                                   ...
# 655543                                                NaN
# 655544                                                NaN
# 655545                                                NaN
# 655546                                                NaN
# 655547  Visual-Wise makes virtual reality accessible t...
#
#                         data.properties.profile_image_url  \
# 0       http://public.crunchbase.com/t_api_images/v147...
# 1       http://public.crunchbase.com/t_api_images/v147...
# 2       http://public.crunchbase.com/t_api_images/v142...
# 3       http://public.crunchbase.com/t_api_images/v142...
# 4       http://public.crunchbase.com/t_api_images/v142...
# ...                                                   ...
# 655543  http://public.crunchbase.com/t_api_images/kxsl...
# 655544                                                NaN
# 655545  http://public.crunchbase.com/t_api_images/acub...
# 655546  http://public.crunchbase.com/t_api_images/jk6f...
# 655547  http://public.crunchbase.com/t_api_images/v142...
#
#        data.properties.primary_role data.properties.founded_on  \
# 0                           company                 2007-01-01
# 1                          investor                 2015-03-04
# 2                           company                 2015-04-15
# 3                           company                        NaN
# 4                           company                 2009-01-01
# ...                             ...                        ...
# 655543                      company                 2017-01-01
# 655544                      company                 1995-04-04
# 655545                      company                        NaN
# 655546                      company                 2018-01-01
# 655547                      company                 2014-08-01
#
#         data.properties.founded_on_trust_code  ...  \
# 0                                         5.0  ...
# 1                                         7.0  ...
# 2                                         7.0  ...
# 3                                         NaN  ...
# 4                                         5.0  ...
# ...                                       ...  ...
# 655543                                    5.0  ...
# 655544                                    7.0  ...
# 655545                                    NaN  ...
# 655546                                    5.0  ...
# 655547                                    7.0  ...
#
#         data.relationships.websites.paging.total_items  \
# 0                                                    3
# 1                                                    2
# 2                                                    2
# 3                                                    2
# 4                                                    3
# ...                                                ...
# 655543                                               1
# 655544                                               0
# 655545                                               1
# 655546                                               1
# 655547                                               2
#
#         data.relationships.websites.paging.first_page_url  \
# 0       https://api.crunchbase.com/v3.1/organizations/...
# 1       https://api.crunchbase.com/v3.1/organizations/...
# 2       https://api.crunchbase.com/v3.1/organizations/...
# 3       https://api.crunchbase.com/v3.1/organizations/...
# 4       https://api.crunchbase.com/v3.1/organizations/...
# ...                                                   ...
# 655543  https://api.crunchbase.com/v3.1/organizations/...
# 655544  https://api.crunchbase.com/v3.1/organizations/...
# 655545  https://api.crunchbase.com/v3.1/organizations/...
# 655546  https://api.crunchbase.com/v3.1/organizations/...
# 655547  https://api.crunchbase.com/v3.1/organizations/...
#
#        data.relationships.websites.paging.sort_order  \
# 0                                        not_ordered
# 1                                        not_ordered
# 2                                        not_ordered
# 3                                        not_ordered
# 4                                        not_ordered
# ...                                              ...
# 655543                                   not_ordered
# 655544                                   not_ordered
# 655545                                   not_ordered
# 655546                                   not_ordered
# 655547                                   not_ordered
#
#                         data.relationships.websites.items  \
# 0       [{'type': 'Website', 'uuid': '5b3e1a8a659038da...
# 1       [{'type': 'Website', 'uuid': '65609a0678e0195e...
# 2       [{'type': 'Website', 'uuid': '2485430c0d4d9009...
# 3       [{'type': 'Website', 'uuid': '48fa12215094286d...
# 4       [{'type': 'Website', 'uuid': 'c127e1bdf8375492...
# ...                                                   ...
# 655543  [{'type': 'Website', 'uuid': '39ea80735fe648c6...
# 655544                                                 []
# 655545  [{'type': 'Website', 'uuid': 'd6574842db074850...
# 655546  [{'type': 'Website', 'uuid': '0cd754a82a124886...
# 655547  [{'type': 'Website', 'uuid': '7c3ce388e31472fb...
#
#                           twitter                               facebook  \
# 0                twitter.com/5mag      http://www.facebook.com/5magazine
# 1         twitter.com/HelloAngels                                    NaN
# 2       www.twitter.com/apiwareio                                    NaN
# 3         twitter.com/Captain_App                                    NaN
# 4        twitter.com/esciencenews  https://www.facebook.com/esciencenews
# ...                           ...                                    ...
# 655543                        NaN                                    NaN
# 655544                        NaN                                    NaN
# 655545                        NaN                                    NaN
# 655546                        NaN                                    NaN
# 655547    twitter.com/Visual_Wise                                    NaN
#
#                               homepage linkedin        fb_key        tw_key
# 0                      http://5mag.co/      NaN     5magazine          5mag
# 1               http://helloangels.co/      NaN           NaN   helloangels
# 2                http://www.apiware.io      NaN           NaN     apiwareio
# 3               http://onecaptain.com/      NaN           NaN   captain_app
# 4             http://esciencenews.com/      NaN  esciencenews  esciencenews
# ...                                ...      ...           ...           ...
# 655543             http://91ylian.com/      NaN           NaN           NaN
# 655544                             NaN      NaN           NaN           NaN
# 655545  https://inaba-serverdesign.jp/      NaN           NaN           NaN
# 655546             http://www.hk4w.com      NaN           NaN           NaN
# 655547    https://www.visual-wise.com/      NaN           NaN   visual_wise
#
# [655548 rows x 23 columns]

# %%
tw_merge= pd.merge(left=cb_df, right=ks_df, left_on='twitter', right_on='twitter')

# %%
tw_merge
# Out:
#                            _id                         data.uuid  \
# 0     5bc4821cf27e62f65c1aa446  d9ae3c821a4ccfc82df968efaca9d774
# 1     5bc4821cf27e62f65c1aa446  d9ae3c821a4ccfc82df968efaca9d774
# 2     5bc4821cf27e62f65c1aa446  d9ae3c821a4ccfc82df968efaca9d774
# 3     5bc4821cf27e62f65c1aa446  d9ae3c821a4ccfc82df968efaca9d774
# 4     5bc4821cf27e62f65c1aa446  d9ae3c821a4ccfc82df968efaca9d774
# ...                        ...                               ...
# 3744  5bc48a55f27e62f65c249a5d  48c5400170c207ad8c9702fd38e49c97
# 3745  5bc48a55f27e62f65c249a5d  48c5400170c207ad8c9702fd38e49c97
# 3746  5bc48a55f27e62f65c249a5d  48c5400170c207ad8c9702fd38e49c97
# 3747  5bc48a55f27e62f65c249a5d  48c5400170c207ad8c9702fd38e49c97
# 3748  5bc48a55f27e62f65c249a5d  48c5400170c207ad8c9702fd38e49c97
#
#        data.properties.name data.properties.also_known_as  \
# 0     1800TravelBooking.com                           NaN
# 1     1800TravelBooking.com                           NaN
# 2     1800TravelBooking.com                           NaN
# 3     1800TravelBooking.com                           NaN
# 4     1800TravelBooking.com                           NaN
# ...                     ...                           ...
# 3744    Zippy Robotics, Inc                           NaN
# 3745    Zippy Robotics, Inc                           NaN
# 3746    Zippy Robotics, Inc                           NaN
# 3747    Zippy Robotics, Inc                           NaN
# 3748    Zippy Robotics, Inc                           NaN
#
#                       data.properties.short_description  \
# 0     1800TravelBooking.com is an Internet-based tra...
# 1     1800TravelBooking.com is an Internet-based tra...
# 2     1800TravelBooking.com is an Internet-based tra...
# 3     1800TravelBooking.com is an Internet-based tra...
# 4     1800TravelBooking.com is an Internet-based tra...
# ...                                                 ...
# 3744  We believe that anyone can make anything. We w...
# 3745  We believe that anyone can make anything. We w...
# 3746  We believe that anyone can make anything. We w...
# 3747  We believe that anyone can make anything. We w...
# 3748  We believe that anyone can make anything. We w...
#
#                             data.properties.description  \
# 0     1800TravelBooking.com is an Internet-based tra...
# 1     1800TravelBooking.com is an Internet-based tra...
# 2     1800TravelBooking.com is an Internet-based tra...
# 3     1800TravelBooking.com is an Internet-based tra...
# 4     1800TravelBooking.com is an Internet-based tra...
# ...                                                 ...
# 3744                                                NaN
# 3745                                                NaN
# 3746                                                NaN
# 3747                                                NaN
# 3748                                                NaN
#
#                       data.properties.profile_image_url  \
# 0     http://public.crunchbase.com/t_api_images/v139...
# 1     http://public.crunchbase.com/t_api_images/v139...
# 2     http://public.crunchbase.com/t_api_images/v139...
# 3     http://public.crunchbase.com/t_api_images/v139...
# 4     http://public.crunchbase.com/t_api_images/v139...
# ...                                                 ...
# 3744  http://public.crunchbase.com/t_api_images/v146...
# 3745  http://public.crunchbase.com/t_api_images/v146...
# 3746  http://public.crunchbase.com/t_api_images/v146...
# 3747  http://public.crunchbase.com/t_api_images/v146...
# 3748  http://public.crunchbase.com/t_api_images/v146...
#
#      data.properties.primary_role data.properties.founded_on  \
# 0                         company                 2006-01-01
# 1                         company                 2006-01-01
# 2                         company                 2006-01-01
# 3                         company                 2006-01-01
# 4                         company                 2006-01-01
# ...                           ...                        ...
# 3744                      company                 2014-01-01
# 3745                      company                 2014-01-01
# 3746                      company                 2014-01-01
# 3747                      company                 2014-01-01
# 3748                      company                 2014-01-01
#
#       data.properties.founded_on_trust_code  ...  \
# 0                                       5.0  ...
# 1                                       5.0  ...
# 2                                       5.0  ...
# 3                                       5.0  ...
# 4                                       5.0  ...
# ...                                     ...  ...
# 3744                                    7.0  ...
# 3745                                    7.0  ...
# 3746                                    7.0  ...
# 3747                                    7.0  ...
# 3748                                    7.0  ...
#
#                           homepage linkedin_x         fb_key         tw_key  \
# 0     http://1800travelbooking.com        NaN            NaN          gpuri
# 1     http://1800travelbooking.com        NaN            NaN          gpuri
# 2     http://1800travelbooking.com        NaN            NaN          gpuri
# 3     http://1800travelbooking.com        NaN            NaN          gpuri
# 4     http://1800travelbooking.com        NaN            NaN          gpuri
# ...                            ...        ...            ...            ...
# 3744  http://www.zippyrobotics.com        NaN  zippyrobotics  zippyrobotics
# 3745  http://www.zippyrobotics.com        NaN  zippyrobotics  zippyrobotics
# 3746  http://www.zippyrobotics.com        NaN  zippyrobotics  zippyrobotics
# 3747  http://www.zippyrobotics.com        NaN  zippyrobotics  zippyrobotics
# 3748  http://www.zippyrobotics.com        NaN  zippyrobotics  zippyrobotics
#
#      facebook_y linkedin_y github email            id type
# 0            []         []     []    []  5.343460e+08    c
# 1            []         []     []    []  5.343460e+08    c
# 2            []         []     []    []  5.343460e+08    c
# 3            []         []     []    []  5.343460e+08    c
# 4            []         []     []    []  5.343460e+08    c
# ...         ...        ...    ...   ...           ...  ...
# 3744         []         []     []    []  1.520167e+09    c
# 3745         []         []     []    []  1.520167e+09    c
# 3746         []         []     []    []  1.520167e+09    c
# 3747         []         []     []    []  1.520167e+09    c
# 3748         []         []     []    []  1.520167e+09    c
#
# [3749 rows x 29 columns]

# %%
tw_merge.at[1445,'homepage']
# Out:
# 'https://jumbominds.com/'
